# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np

# %%
x,y = load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg = SGDRegressor(penalty='12', max_iter=500, eta0=0.1, learning_rate='constant', alpha=0.001)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import r2_score

reg = SGDRegressor(
    penalty='l2',
    max_iter=1000,
    tol=1e-3,
    random_state=42
)

reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)

print("R2 score:", r2_score(y_test, y_pred))
print("Coefficients:", reg.coef_)
print("Intercept:", reg.intercept_)
# Out:
# R2 score: 0.3973401883541149
# Coefficients: [  60.60362623  -43.22688972  246.78219524  189.99271062   42.69939975
#    12.28901794 -141.16143602  138.26512944  232.64826475  115.82925217]
# Intercept: [151.41845609]
# C:\Users\sayee\anaconda34\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1620: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=0.001, max_iter =500, solver='sparse_cg')

# %%
reg.fit(x_train, y_train)

y_pred =  reg.predict(x_test)
print("R2 score", r2_score(y_test, y_pred))
print(reg.coef_)
print(reg.intercept_)
# Out:
# R2 score 0.4625010162009602
# [  34.52192661 -290.84083974  482.4018151   368.06786776 -852.44872998
#   501.59160516  180.11115631  270.76334212  759.73534588   37.49135628]
# 151.10198517848258

# %%
class MeraRidgeGD:

    def __init__(self,epochs, learning_rate, alpha):

        self.learning_rate = learning_rate
        self.epochs = epochs
        self.alpha = alpha
        self.coef_ = None
        self.intercept_= None
    def fit(self, X_train, y_train):

        self.coef_ = np.ones(x_train.shape[1])
        self.intercept_ = 0
        thetha  =  np.insert(self.coef_0, self.intercept_)

        x_train = np.insert(x_train,0,1, axis=1)

        for i in range(self.epochs):
            thetha_der = np.dor(x_train.T,x_train).dot(thetha) - np.dot(x_train.T, y_train)-self.alpha*thetha
            thetha = thetha - self.learning_rate*thetha_der

            self.coef_ = thetha[1:]
            self.intercept_ = thetha[0]

    def predict(self, x_test):
         return np.dot(x_test, self.coef_) + self.intercept_

# %%
reg =  MeraRidgeGD(epochs=500, alpha=0.001, learning_rate=0.005)

# %%
def fit(self, x, y):
    self.coef_ = np.ones(x.shape[1])
    self.intercept_ = 0

    thetha = np.insert(self.coef_, 0, self.intercept_)

    for i in range(1000):
        y_hat = np.dot(x, self.coef_) + self.intercept_

    return self

# %%
def fit(self, x, y):
    self.coef_ = np.ones(x.shape[1])
    self.intercept_ = 0
    
    thetha = np.insert(self.coef_, 0, self.intercept_)
    
    # rest of your code...

# %%
import numpy as np

class MeraSGDRegressor:

    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.coef_ = None
        self.intercept_ = None

    def fit(self, x, y):

        # Initialize coefficients
        self.coef_ = np.ones(x.shape[1])
        self.intercept_ = 0

        # Combine coefficients and intercept
        theta = np.insert(self.coef_, 0, self.intercept_)

        # Add column of 1s for intercept
        x = np.insert(x, 0, 1, axis=1)

        # Gradient Descent
        for i in range(self.epochs):

            y_pred = np.dot(x, theta)

            gradient = -(2 / x.shape[0]) * np.dot(
                x.T, (y - y_pred)
            )

            theta = theta - self.learning_rate * gradient

        # Store values
        self.intercept_ = theta[0]
        self.coef_ = theta[1:]

        return self

    def predict(self, x):

        return np.dot(x, self.coef_) + self.intercept_"
# Out:
#   Cell In[39], line 42
#     return np.dot(x, self.coef_) + self.intercept_"
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 42)
