# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"E:\archive (3)\Student_Placement_Record.csv")

# %%
df
# Out:
#       cgpa  placement_exam_marks college_tier  internship_experience  \
# 0     7.19                 26.00       Tier 2                      1
# 1     7.46                 38.00       Tier 3                      1
# 2     7.54                 40.00       Tier 1                      0
# 3     6.42                  8.00       Tier 3                      0
# 4     7.23                 17.00       Tier 2                      0
# ...    ...                   ...          ...                    ...
# 1245  9.21                 24.13       Tier 2                      1
# 1246  7.21                 33.35       Tier 2                      1
# 1247  9.37                 13.11       Tier 2                      0
# 1248  9.35                 48.98       Tier 2                      1
# 1249  8.91                 49.45       Tier 2                      1
#
#       placement
# 0             0
# 1             1
# 2             0
# 3             1
# 4             1
# ...         ...
# 1245          0
# 1246          1
# 1247          0
# 1248          1
# 1249          1
#
# [1250 rows x 5 columns]

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks college_tier  internship_experience  placement
# 0  7.19                  26.0       Tier 2                      1          0
# 1  7.46                  38.0       Tier 3                      1          1
# 2  7.54                  40.0       Tier 1                      0          0
# 3  6.42                   8.0       Tier 3                      0          1
# 4  7.23                  17.0       Tier 2                      0          1

# %%
df.tail()
# Out:
#       cgpa  placement_exam_marks college_tier  internship_experience  \
# 1245  9.21                 24.13       Tier 2                      1
# 1246  7.21                 33.35       Tier 2                      1
# 1247  9.37                 13.11       Tier 2                      0
# 1248  9.35                 48.98       Tier 2                      1
# 1249  8.91                 49.45       Tier 2                      1
#
#       placement
# 1245          0
# 1246          1
# 1247          0
# 1248          1
# 1249          1

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks  internship_experience   placement
# count  1250.000000           1250.000000            1250.000000  1250.00000
# mean      7.061304             31.833608               0.510400     0.56960
# std       0.790968             17.947504               0.500092     0.49533
# min       4.890000              0.000000               0.000000     0.00000
# 25%       6.530000             17.872500               0.000000     0.00000
# 50%       6.990000             29.000000               1.000000     1.00000
# 75%       7.510000             43.000000               1.000000     1.00000
# max       9.450000            100.000000               1.000000     1.00000

# %%
df['cgpa'].mean()
# Out:
# np.float64(7.061304000000001)

# %%
df['placement'].mean()
# Out:
# np.float64(0.5696)

# %%
df.isnull()
# Out:
#        cgpa  placement_exam_marks  college_tier  internship_experience  \
# 0     False                 False         False                  False
# 1     False                 False         False                  False
# 2     False                 False         False                  False
# 3     False                 False         False                  False
# 4     False                 False         False                  False
# ...     ...                   ...           ...                    ...
# 1245  False                 False         False                  False
# 1246  False                 False         False                  False
# 1247  False                 False         False                  False
# 1248  False                 False         False                  False
# 1249  False                 False         False                  False
#
#       placement
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 1245      False
# 1246      False
# 1247      False
# 1248      False
# 1249      False
#
# [1250 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['cgpa', 'placement_exam_marks', 'college_tier', 'internship_experience',
#        'placement'],
#       dtype='object')

# %%
plt.scatter(df['cgpa'],df['placement'])
plt.xlabel('CGPA')
plt.ylabel('placement')
# Out:
# Text(0, 0.5, 'placement')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
x
# Out:
#       cgpa
# 0     7.19
# 1     7.46
# 2     7.54
# 3     6.42
# 4     7.23
# ...    ...
# 1245  9.21
# 1246  7.21
# 1247  9.37
# 1248  9.35
# 1249  8.91
#
# [1250 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#       cgpa
# 814   7.78
# 318   6.74
# 777   7.67
# 232   7.77
# 610   7.32
# ...    ...
# 711   6.97
# 1056  5.85
# 508   6.41
# 513   6.43
# 927   7.37
#
# [250 rows x 1 columns]

# %%
y_test
# Out:
# 814     1
# 318     0
# 777     1
# 232     0
# 610     1
#        ..
# 711     1
# 1056    1
# 508     1
# 513     1
# 927     1
# Name: placement, Length: 250, dtype: int64

# %%
x_train
# Out:
#       cgpa
# 496   7.52
# 283   7.09
# 532   6.90
# 704   6.91
# 1248  9.35
# ...    ...
# 466   6.45
# 299   6.75
# 493   6.80
# 527   7.72
# 1192  9.10
#
# [1000 rows x 1 columns]

# %%
y_train
# Out:
# 496     1
# 283     1
# 532     1
# 704     1
# 1248    1
#        ..
# 466     0
# 299     0
# 493     1
# 527     1
# 1192    1
# Name: placement, Length: 1000, dtype: int64

# %%
lr.predict(x_test.iloc[2].values.reshape(1,1))
# Out:
# C:\Users\sayee\anaconda34\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.63085484])

# %%
plt.scatter(df['cgpa'],df['placement'])
plt.plot('cgpa'),lr.predict(x_test)
plt.xlabel('CGPA')
plt.ylabel('placement')
# Out:
# Text(0, 0.5, 'placement')

# %%
m = lr.coef_

# %%
c = lr.intercept_

# %%
# y =mx +c
m*7.78 + c
# Out:
# array([0.64311407])

# %%
m*100 + c
# Out:
# array([10.92080758])
