# %%
a = 5
print(type(a)) # inbuilt class
# Out:
# <class 'int'>

# %%
l = [5,6,7]
print(type(l))
# Out:
# <class 'list'>

# %%
def greet():
    print('welcome')
greet()
# Out:
# welcome

# %%
class wish:
    def greet():
        print('welcome')
w = greet()
# Out:
# welcome

# %%
class computer():
    def config():
        print('i5', '8gb')
com1 = computer()   

computer.config()
# Out:
# i5 8gb

# %%
class computer():
    def config():
        print('i5', '8gb')
com1 = computer()
com1

# %%
class computer():
    def config(self):
        print('i5', '8gb')

com1 = computer()
com1.config()
# Out:
# i5 8gb

# %%
class computer():
    def config(self):
        print('i5', '8gb')

com1 = computer()
com2 = computer()

com1.config()
# Out:
# i5 8gb

# %%
class computer():
    def config(self):
        print('i5','8gb')

com1 = computer()
com2 = computer()


com1.config()
com2.config()
# Out:
# i5 8gb
# i5 8gb

# %%
class computer:
    def config():
        print('i5', '8gb')

a = 8
print(type(a))

com1 = computer()
print(type(com1))
# Out:
# <class 'int'>
# <class '__main__.computer'>

# %%
class computer():
    def config(self):
        print('i5','8gb')

com1 = computer()
com2 = computer()
com3 = computer()

com1.config()
com2.config()
com3.config()


print(id(com1))
print(id(com2))
print(id(com3))
# Out:
# i5 8gb
# i5 8gb
# i5 8gb
# 2119357422560
# 2119355381904
# 2119355381264

# %%
class computer:
    def config(self):
        print('i5', '8gb')
com1 = computer()
com1.config()
# Out:
# i5 8gb

# %%
class computer:
    def __init__(self):
        print('i5','8gb')

com1 = computer()
com2 = computer()
com3 = computer()

print(id(com1))
print(id(com2))
# Out:
# i5 8gb
# i5 8gb
# i5 8gb
# 2119357422896
# 2119355381264

# %%
class computer:
    def confi(self):
        print('i5','8gb')

com1 = computer()

class computer:
    def __init__(self):
        print('i5','8gb')
com1 = computer()
# Out:
# i5 8gb

# %%
class computer:
    def config(self):
        print('i5','8gb')

    def __init__(self):
        print('i5','8gb')

com1 = computer()
# Out:
# i5 8gb

# %%
class computer:

    def __init__(self):
        print('i5', '8gb')
    def config(self):
        print('i7', '16gb')

com1 = computer()
com2 = computer()
com1.config()
# Out:
# i5 8gb
# i5 8gb
# i7 16gb

# %% [markdown]
# # day 2

# %%
class computer:

    def __init__(delf):
        print('in init')
    def config(self):
         print('i5', '8gb')
com1 = computer()
# Out:
# in init

# %%
class computer:
    def __init__(self):
        print('in init')
    def config(self):
         print('i5', '8bg')
com1 = computer()
com1.config()
# Out:
# in init
# i5 8bg

# %%
class computer:
    def config(self):
        print('i5', '8gb')

    def config2(self):
            print('i7', '32gb')
    def __init__(self):
         print('in init')

com1 = computer()
com2 = computer()

com2.config2()
# Out:
# in init
# in init
# i7 32gb

# %% [markdown]
# # Method with Arguments

# %%
class computer:
    def __init__(self, cpu, ram):
        print('in init')
    def config (self):
        print('i5', '8gb')
        print('i7', 16)

com1 = computer('i5', 8)
com2 = computer('i7', 16)

com1.config()
com2.config()
# Out:
# in init
# in init
# i5 8gb
# i7 16
# i5 8gb
# i7 16

# %%
class computer:
    def __init__(self, cpu, ram, price):
        print('in init')
    def config(self):
        print('i5', '8gb', 50000)
        print('i7', 16, 100000)
com1  = computer('i5', 8, 500)
com2  = computer('i7', 16, 10000)

com1.config()
com2.config()
# Out:
# in init
# in init
# i5 8gb 50000
# i7 16 100000
# i5 8gb 50000
# i7 16 100000

# %%
class computer:
    def __init__(self, cpu, ram):
        self.cpu = cpu
        self.ram = ram

    def config(self):
        print('config is', self.cpu, self.ram)

com1 = computer('i5', 8)
com2 = computer('i7', 16)

com1.config()
com2.config()
# Out:
# config is i5 8
# config is i7 16

# %%
class computer:
    def __init__(self, cpu, ram, ssd):
        self.cpu = cpu
        self.ram = ram
        self.ssd = ssd

    def config(self):
        print('config is', self.cpu, self.ram, self.ssd)

com1 = computer('i5', 8, 256)
com2 = computer('i7', 16, 512)


com1.config()
com2.config()
# Out:
# config is i5 8 256
# config is i7 16 512

# %%
class computer:

    def __init__(self, cpu, ram, mem, brand):
        self.cpu = cpu
        self.ram = ram
        self.mem  = mem
        self.brand = brand

    def config(self):
         print('config is', self.cpu, self, self.ram, self.mem, self.brand)

com1 = computer('i5', 8, 256, 'hp')
com2 = computer('i7' ,16, 512, 'lenovo')


com1.config()
com2.config()

print(id(com1))
print(id(com2))
# Out:
# config is i5 <__main__.computer object at 0x000001ED738BE3C0> 8 256 hp
# config is i7 <__main__.computer object at 0x000001ED736CB890> 16 512 lenovo
# 2119357424576
# 2119355381904

# %% [markdown]
# # Self  & constructor

# %%
class computer:
    pass
c1 = computer()
print(id(c1))
# Out:
# 2119357428944

# %%
class computer:
    pass

c1 = computer()
c2 = computer()

print(id(c1))
print(id(c2))
# Out:
# 2119357429280
# 2119358006288

# %%
class computer:
    def __init__(self):
        self.name = 'akash'
        self.age = 37

c1 = computer()
c2 = computer()


print(c1.name, c1.age)
print(c2.name, c2.age)
# Out:
# akash 37
# akash 37

# %%
class computer:
    def __init__(self):
        self.name = 'sayeed'
        self.age = 23

    c1 = computer()
    c2 = computer()
    c2.age = '23'
    c2.age = '23'


print(c1.name, c1.age)
print(c2.name, c2.age)
# Out:
# akash 37
# akash 23

# %% [markdown]
# # Encapsulation

# %%
class car:
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

print(c1.com, c1.mil)
print(c2.com, c2.mil)

print(id(c1))
print(id(c2))
# Out:
# bmw 10
# bmw 10
# 2119357429280
# 2119358010448

# %%
class car:
    def __init__(self):
        self.mil = 10
        self.com = 'bmw'
        
c1 = car()
c2 = car()

c2.com = 'swift'
c2.mil = 18
c1.mil = 11

print(c1.com, c1.mil)
print(c2.com, c2.mil)
# Out:
# bmw 11
# swift 18

# %% [markdown]
# # class variable

# %%
class car():

    wheels = 5   # class variable or static variable 
    
    def __init__(self):
        self.mil = 10      #INSTANCE 
        self.com = 'bmw'   #INSTANCE 
        
c1 = car()
c2 = car()

print(c1.com, c1.mil, c1.wheels)
print(c2.com, c2.mil, c2.wheels)
# Out:
# bmw 10 5
# bmw 10 5

# %%
class car():

    wheels = 5   # class variable or static variable 
    
    def __init__(self):
        self.mil = 10      #INSTANCE 
        self.com = 'bmw'   #INSTANCE 
        
c1 = car()
c2 = car()

c1.com = 'toyota'
c1.mil = 15
c1.wheels = 6


print(c1.com, c1.mil, c1.wheels)
print(c2.com, c2.mil, c2.wheels)
# Out:
# toyota 15 6
# bmw 10 5

# %% [markdown]
# # Instance method, class method , static method

# %%
class student:  # class name 
        
    school = 'nit'   # class varibale
    
    def __init__(self, m1, m2, m3) :  #special method with 4 arg
        self.m1 = m1 #inst
        self.m2 = m2 #inst
        self.m3 = m3 #inst

    def mean(self):  #avg is instnce method   
        return (self.m1+self.m2+self.m3)/3
    
s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

print(s1.mean())
print(s2.mean())

print(s1.m1)
print(s1.m2)
print(s2.m2)
# Out:
# 20.0
# 10.0
# 10
# 20
# 15

# %% [markdown]
# # class method

# %%
class student: 
        
    school = 'nit' 
    
    def __init__(self, m1, m2, m3) : 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):  # instance method 
        return (self.m1+self.m2+self.m3)/3
    
    def info(cls):  # class method 
        return cls.school 
        

s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

print(s1.avg()) 
print(s2.avg())

print(s1.info()) 
print(s2.info())

#print(student.info())
# Out:
# 20.0
# 10.0
# nit
# nit

# %%
class student:        
    school = 'nit'     
    def __init__(self, m1, m2, m3) : 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3
        
    def avg(self):  # instance method 
        return (self.m1+self.m2+self.m3)/3  
        
    @classmethod   
    def info(cls):  # class method 
        return cls.school  
        
s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

s1.info()
# Out:
# 'nit'

# %% [markdown]
# # Static method

# %%
class student: 
        
    school = 'nit'
    
    def __init__(self, m1, m2, m3) : # hear i pass 3 variable 
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self):   # ------> hear this average is INSTANCE METHOD 
        return (self.m1+self.m2+self.m3)/3
    
    @classmethod
    def getSchool(cls):
        return cls.school
    
    @staticmethod 
    def info():
        print('this is student class') 
        
# lets create  object hear as we created s1, s2 we created 2 object & also i want to pass value in this  
s1 = student(10, 20, 30)
s2 = student(5, 15, 10)

print(s1.avg())
print(s2.avg())

print(s1.getSchool())
print(s2.getSchool())

s1.info()
s2.info()
# Out:
# 20.0
# 10.0
# nit
# nit
# this is student class
# this is student class
