# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
! pip install wget
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9712 sha256=dbbd49235fd4781d71b008ba45257278ab1cfb96e2fecb1c4ec86b73cc5dfca6
#   Stored in directory: c:\users\sayee\appdata\local\pip\cache\wheels\8a\b8\04\0c88fb22489b0c049bee4e977c5689c7fe597d6c4b0e7d0b6a
# Successfully built wget
# ...
#   DEPRECATION: Building 'wget' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wget'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !gunzip GoogleNews-vectors-negative300.bin.gz
# Out:
# 'gunzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os

print(os.path.exists("GoogleNews-vectors-negative300.bin"))
# Out:
# False

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\sayee

# %%
os.listdir()
# Out:
# ['-list.python.yaml',
#  '.agents',
#  '.anaconda',
#  '.cache',
#  '.conda',
#  '.config',
#  '.continuum',
#  '.copilot',
#  '.cursor',
#  '.git',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.lesshst',
#  '.matplotlib',
#  '.ms-ad',
#  '.ollama',
#  '.python_history',
#  '.redhat',
#  '.spyder-py3',
#  '.ssh',
#  '.streamlit',
#  '.viminfo',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-shared',
#  '1',
#  '6th_task.ipynb',
#  '8th_task.ipynb',
#  'ai-song-generator',
#  'AI.ipynb',
#  'anaconda3',
#  'anaconda34',
#  'AppData',
#  'Application Data',
#  'bank risk analysis.ipynb',
#  'class  & object.ipynb',
#  'class & object.ipynb',
#  'class and objects49.ipynb',
#  'class.ipynb',
#  'cleaned_employee_data.xlsx',
#  'clean_data.csv',
#  'column.transformation.ipynb',
#  'Contacts',
#  'Cookies',
#  'country economics analysis.ipynb',
#  'CrossDevice',
#  'data.ipynb',
#  'dataset_1_202606171043.csv',
# ...

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os

print(os.path.exists("GoogleNews-vectors-negative300.bin.gz"))
# Out:
# False

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sayee

# %%
os.listdir()
# Out:
# ['-list.python.yaml',
#  '.agents',
#  '.anaconda',
#  '.cache',
#  '.conda',
#  '.config',
#  '.continuum',
#  '.copilot',
#  '.cursor',
#  '.git',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.lesshst',
#  '.matplotlib',
#  '.ms-ad',
#  '.ollama',
#  '.python_history',
#  '.redhat',
#  '.spyder-py3',
#  '.ssh',
#  '.streamlit',
#  '.viminfo',
#  '.virtual_documents',
#  '.vscode',
#  '.vscode-shared',
#  '1',
#  '6th_task.ipynb',
#  '8th_task.ipynb',
#  'ai-song-generator',
#  'AI.ipynb',
#  'anaconda3',
#  'anaconda34',
#  'AppData',
#  'Application Data',
#  'bank risk analysis.ipynb',
#  'class  & object.ipynb',
#  'class & object.ipynb',
#  'class and objects49.ipynb',
#  'class.ipynb',
#  'cleaned_employee_data.xlsx',
#  'clean_data.csv',
#  'column.transformation.ipynb',
#  'Contacts',
#  'Cookies',
#  'country economics analysis.ipynb',
#  'CrossDevice',
#  'data.ipynb',
#  'dataset_1_202606171043.csv',
# ...

# %%
# !pip install gensim
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gensim.downloader as api

model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
model.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824870705604553),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549197196960449),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372579574584961),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985372543335)]

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563532590866089),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529867649078369),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367617845535278),
#  ('linkedin', 0.6356592774391174)]

# %%
model.similarity('man','woman')
# Out:
# np.float32(0.7664012)

# %%
model.similarity('man','PHP')
# Out:
# np.float32(-0.032995157)

# %%
model.doesnt_match(['PHP','java','monkey'])
# Out:
# 'monkey'

# %%
vec = model['king'] - model['man'] +  model['women']
model.most_similar([vec])
# Out:
# [('king', 0.6478992104530334),
#  ('queen', 0.5354938507080078),
#  ('women', 0.52336585521698),
#  ('kings', 0.5162314772605896),
#  ('queens', 0.499536395072937),
#  ('kumaris', 0.49238473176956177),
#  ('princes', 0.46233269572257996),
#  ('monarch', 0.45280295610427856),
#  ('monarchy', 0.4293173849582672),
#  ('kings_princes', 0.42342400550842285)]

# %%
vec = model['INR'] - model['man'] + model['women']
model.most_similar([vec])
# Out:
# [('INR', 0.7815766930580139),
#  ('Rs', 0.5698786377906799),
#  ('Rs1', 0.5438748598098755),
#  ('Rs###mn', 0.5423610210418701),
#  ('Rs##', 0.5263841152191162),
#  ('Rs.2', 0.5249857902526855),
#  ('Rs.##', 0.524847686290741),
#  ('Rs.6', 0.5240983963012695),
#  ('Rs.1', 0.5238142609596252),
#  ('Rs.8', 0.5154834985733032)]

# %%
import numpy as np
import pandas as pd

# %%
# ! pip install gensim

# %%
import gensim
import os

# %%
import os
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []

folder_path = r"E:\archive (3)"

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    with open(file_path, "r", encoding="cp1252") as f:
        corpus = f.read()

    raw_sent = sent_tokenize(corpus)

    for sent in raw_sent:
        story.append(simple_preprocess(sent))

print("Total sentences:", len(story))
print(story[:5])
# Out:
# Total sentences: 145020
# [['game', 'of', 'thrones', 'book', 'one', 'of', 'song', 'of', 'ice', 'and', 'fire', 'by', 'george', 'martin', 'prologue', 'we', 'should', 'start', 'back', 'gared', 'urged', 'as', 'the', 'woods', 'began', 'to', 'grow', 'dark', 'around', 'them'], ['the', 'wildlings', 'are', 'dead'], ['do', 'the', 'dead', 'frighten', 'you'], ['ser', 'waymar', 'royce', 'asked', 'with', 'just', 'the', 'hint', 'of', 'smile'], ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait']]

# %%
len(story)
# Out:
# 145020

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
import gensim

model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers=4
)

# %%
model.build_vocab(story)

# %%
model.train(
    story,
    total_examples=model.corpus_count,
    epochs=model.epochs
)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# (6569599, 8628190)

# %%
import numpy
import gensim

print("NumPy:", numpy.__version__)
print("Gensim:", gensim.__version__)
# Out:
# NumPy: 2.3.5
# Gensim: 4.4.0

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.7505250573158264),
#  ('targaryen', 0.6696677207946777),
#  ('viserys', 0.6375988125801086),
#  ('khaleesi', 0.6262691020965576),
#  ('unburnt', 0.623655378818512),
#  ('dragons', 0.6058050990104675),
#  ('daxos', 0.5800577402114868),
#  ('elia', 0.578254759311676),
#  ('xaro', 0.5727434754371643),
#  ('dorne', 0.5723486542701721)]

# %%
model.wv.doesnt_match(['john','rikon','arya','sansa','bran'])
# Out:
# 'john'

# %%
model.wv.doesnt_match(['cersei','jaime','bronn','tyrion'])
# Out:
# 'bronn'

# %%
model.wv['king'].shape
# Out:
# (100,)

# %%
model.wv.similarity('arya','sansa')
# Out:
# np.float32(0.781111)

# %%
model.wv.similarity('cersei','sansa')
# Out:
# np.float32(0.6438513)

# %%
model.wv.similarity('tywin','sansa')
# Out:
# np.float32(0.18503463)

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.1671356 ,  0.02219062,  0.14774041, ..., -0.04550226,
#         -0.09039769,  0.0293179 ],
#        [-0.09686397,  0.1302895 ,  0.14389955, ...,  0.08853515,
#         -0.02787286,  0.02865786],
#        [ 0.13774191, -0.09242371,  0.03158825, ..., -0.04407371,
#          0.06259546, -0.06202519],
#        ...,
#        [ 0.02844579, -0.00197089,  0.09059931, ...,  0.05944068,
#          0.00752437, -0.10208295],
#        [ 0.05833763, -0.0268268 ,  0.14175464, ..., -0.16636983,
#          0.11413021, -0.11182139],
#        [ 0.147929  , -0.02797657,  0.05514913, ...,  0.03739842,
#          0.17647505, -0.04778558]], shape=(17453, 100), dtype=float32)

# %%
y = model.wv.index_to_key

# %%
y
# Out:
# ['the',
#  'and',
#  'to',
#  'of',
#  'he',
#  'his',
#  'was',
#  'you',
#  'her',
#  'in',
#  'it',
#  'had',
#  'that',
#  'she',
#  'as',
#  'with',
#  'him',
#  'not',
#  'but',
#  'for',
#  'they',
#  'is',
#  'at',
#  'on',
#  'said',
#  'my',
#  'have',
#  'be',
#  'lord',
#  'them',
#  'no',
#  'from',
#  'would',
#  'were',
#  'me',
#  'your',
#  'one',
#  'all',
#  'when',
#  'will',
#  'ser',
#  'if',
#  'so',
#  'their',
#  'we',
#  'could',
#  'are',
#  'man',
#  'there',
#  'this',
#  'up',
#  'been',
#  'what',
#  'did',
#  'by',
#  'king',
#  'do',
#  'men',
#  'back',
#  'out',
#  'more',
#  'or',
#  'who',
#  'down',
#  'well',
#  'than',
#  'only',
#  'like',
#  'jon',
#  'some',
#  'father',
#  'old',
#  'hand',
#  'even',
#  'too',
#  'tyrion',
#  'before',
#  'never',
#  'an',
#  'off',
#  'know',
#  'see',
#  'into',
#  'made',
#  'now',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'time',
#  'then',
#  'how',
#  'long',
#  'has',
#  'can',
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
x = pca.fit_transform(model.wv.get_normed_vectors())

# %%
x
# Out:
# array([[ 0.25507388, -0.3400029 , -0.02349918],
#        [ 0.20615987, -0.17737806,  0.01284532],
#        [-0.09423251, -0.53789204,  0.0942625 ],
#        ...,
#        [-0.23670079,  0.13200742,  0.01839265],
#        [-0.05211924,  0.21849757, -0.22041959],
#        [ 0.02422386, -0.5050918 ,  0.16412145]],
#       shape=(17453, 3), dtype=float32)

# %%
# !pip install plotly
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly.express as px

fig = px.scatter_3d(
    x=x[:500, 0],
    y=x[:500, 1],
    z=x[:500, 2],
    color=y[:500]
)

fig.show()
