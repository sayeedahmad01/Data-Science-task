# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\archive\Placement_data.csv")

# %%
df
# Out:
#                  Name  Roll No  Branch  Gender  CGPA  10th_percentage  \
# 0     William Johnson  3913839  CSAIML    Male  4.42            95.60
# 1       John Martinez  5382514    CSDS    Male  4.13            72.06
# 2        Ashley Smith  6830292    CSDS  Female  6.43            54.90
# 3          Ann Wilson  2963711    CSDS  Female  5.24            72.51
# 4    Rebecca Peterson  2075489      IT  Female  7.15            69.53
# ..                ...      ...     ...     ...   ...              ...
# 995    Emily Schwartz  6515921    CSAI  Female  5.56            79.20
# 996    Samantha Green  6630819    CSDS  Female  8.62            77.84
# 997    Michael Torres  7734526    AIDS    Male  4.21            53.98
# 998    Jason Phillips  9443358     EEE    Male  5.06            85.25
# 999   William Griffin  2228828    CSAI    Male  5.53            81.51
#
#      12th_percentage Project Level Internships Certifications  Backlogs  \
# 0              54.02      Advanced         Yes             No         0
# 1              51.38      Beginner          No             No         0
# 2              68.79      Moderate          No            Yes         2
# 3              61.97      Moderate          No            Yes         0
# 4              55.80      Advanced         Yes             No         0
# ..               ...           ...         ...            ...       ...
# 995            96.17      Moderate         Yes             No         5
# 996            82.97      Beginner          No            Yes         5
# 997            91.34      Advanced         Yes            Yes         3
# 998            92.86      Moderate          No             No         4
# 999            53.40      Advanced          No             No         0
#
#      Placed
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
# ..      ...
# 995       0
# 996       0
# 997       0
# 998       0
# 999       0
#
# [1000 rows x 12 columns]

# %%
print(df.shape)
df.head()
# Out:
# (1000, 12)
#                Name  Roll No  Branch  Gender  CGPA  10th_percentage  \
# 0   William Johnson  3913839  CSAIML    Male  4.42            95.60
# 1     John Martinez  5382514    CSDS    Male  4.13            72.06
# 2      Ashley Smith  6830292    CSDS  Female  6.43            54.90
# 3        Ann Wilson  2963711    CSDS  Female  5.24            72.51
# 4  Rebecca Peterson  2075489      IT  Female  7.15            69.53
#
#    12th_percentage Project Level Internships Certifications  Backlogs  Placed
# 0            54.02      Advanced         Yes             No         0       0
# 1            51.38      Beginner          No             No         0       0
# 2            68.79      Moderate          No            Yes         2       0
# 3            61.97      Moderate          No            Yes         0       0
# 4            55.80      Advanced         Yes             No         0       1

# %%
sns.stripplot(
    data=df,
    x='Project Level',
    y='CGPA',
    hue='Placed'
)
# Out:
# <Axes: xlabel='Project Level', ylabel='CGPA'>

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
print(x.dtypes)
# Out:
# Name       object
# Roll No     int64
# dtype: object

# %%
x = df.drop(columns=['Name', 'Placed'])
y = df['Placed']

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
p.fit(x, y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 1.854071e+06,  5.077270e+03, -2.461540e+03,  7.900600e+02,
#         -1.154000e+03, -3.200000e+01,  4.000000e+00,  1.700000e+01,
#          1.800000e+01, -9.000000e+01,  5.100000e+01,  7.000000e+01,
#          4.300000e+01,  1.500000e+01, -1.300000e+02, -3.400000e+01,
#          2.940000e+02,  3.900000e+01]])

# %%
p.intercept_
# Out:
# array([-9.])

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\sayee\anaconda34\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\sayee\anaconda34\lib\site-packages (from mlxtend) (2.5.2)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\sayee\anaconda34\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\sayee\anaconda34\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\sayee\anaconda34\lib\site-packages (from mlxtend) (3.11.1)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\sayee\anaconda34\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayee\anaconda34\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sayee\anaconda34\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sayee\anaconda34\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sayee\anaconda34\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\sayee\anaconda34\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.7.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\sayee\anaconda34\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Using cached mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.25.0
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\sayee\anaconda34\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\sayee\anaconda34\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\sayee\anaconda34\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
x_plot = x.iloc[:, [0, 1]]

p.fit(x_plot, y)

plot_decision_regions(
    x_plot.values,
    y.values,
    clf=p,
    legend=2
)

plt.show()
# Out:
# C:\Users\sayee\anaconda34\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   -------
